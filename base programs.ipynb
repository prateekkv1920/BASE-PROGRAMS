# %% [markdown]
# # Samatrix Assignment Problem

# %% [markdown]
# Write a program to calculate the area of the room. Your program should ask the user to enter the width and length of the room. The user should enter the value in unit feet. Once the program reads the values, it should compute the area and display the same. You should include the unit (feet) in your input and output message

# %%
le=float(input("enter the length in feet"))
br=float(input("enter the breath in feet"))
ar=le*br
print(f"{ar} area of the room for length {le} and breath {br}" )
# Out:
# enter the length in feet334
# enter the breath in feet4
# 1336.0 area of the room for length 334.0 and breath 4.0

# %% [markdown]
# # Write a python program for arithmetic calculations. The program should ask for two integers,  and , from the user. The program should compute and display the following:
# The sum of  a and b
#
# The difference when b is subtracted from a
#
# The product of a and b
#
# The quotient when a is divided by b
#
# The remainder when a is divided by b
#
# The result of log10 a
#
# The result of a^b

# %%
import math
while True:
    choice=input("enter choice-addition, subtract, product, divide, floor_division, log10a, power")
    if choice in ('addition','subtract','product','divide','floor_division','log10a','power'):
        try:
            a=float(input("enter the a integer"))
            b=float(input("enter the b integer"))
        except:
            print("invalid input")
            continue
        if choice=='addition':
            print("addition ",a+b)
        elif choice=='subtract':
            print('subtract',a-b)
        elif choice=='product':
            print('product',a*b)
        elif choice=='divide':
            print('divide',a/b)
        elif choice=='floor_division':
            print('floor_division',a/b)
        elif choice=='log10a':
            print('log10a',math.log10(a))
        elif choice=='power':
            print('power',a**b)
        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "no":
          break
    else:
        print("Invalid Input")
# Out:
# enter choice-addition, subtract, product, divide, floor_division, log10a, powerlog10a
# enter the a integer10
# enter the b integer2
# log10a 1.0
# Let's do next calculation? (yes/no): yes
# enter choice-addition, subtract, product, divide, floor_division, log10a, poweradditon
# Invalid Input
# enter choice-addition, subtract, product, divide, floor_division, log10a, poweraddition
# enter the a integer21
# enter the b integer21
# addition  42.0
# Let's do next calculation? (yes/no): no

# %% [markdown]
# # Write a program to display the sorted order of three integers that the user will input. You can use min and max functions to find the smallest and largest values. Then you can find the middle value by adding all the three values and then subtracting minimum and maximum value.

# %%
a=int(input("enter the first number"))
b=int(input("enter the first number"))
c=int(input("enter the first number"))
li=[a,b,c]
s=li.sort
print(li)
print("sorted",li)
ma=max(li)
print("max value",ma)
mi=min(li)
print("min value",mi)
s=a+b+c
print("sum of three ",s)
print("mid value : ",s-(ma+mi))
# Out:
# enter the first number32
# enter the first number324
# enter the first number442
# [32, 324, 442]
# sorted [32, 324, 442]
# max value 442
# min value 32
# sum of three  798
# mid value :  324

# %% [markdown]
# # Write a python program to determine the name of a shape from the number of sides. The program should prompt the user to enter the number of sides. It should give the appropriate name as part of a meaningful message. The program should support shapes with anywhere from 3 up to (and including) 10 sides. If a number of sides are outside of the range that is entered then your program should display an appropriate error message.

# %%
s=int(input("enter the no of sides from 3 to 10 :"))
if 3<=s<=10:
    if s==3:
        shape="triangle"
    elif s==4:
        print("shape-qudrilateral")
    elif s==5:
        print("shape-pentagon")
    elif s==6:
        print("shape-hexagon")
    elif s==7:
        print("shape-heptagon")
    elif s==8:
        print("shape-octagon")
    elif s==9:
        print("shape-nonagon")
    elif s==10:
        print("shape-decagon")
    else:
        print("shape-not defined")
else:
    print("invalid shape")
# Out:
# enter the no of sides from 3 to 10 :4
# shape-qudrilateral

# %% [markdown]
# # Many astrologers use the position of the sun at the time of child birth to predict the future. According to this system of astrology, we can divide the year into twelve zodiac signs time of one’s birth to try and predict the future. This system of astrology divides the year into twelve zodiac signs, as outline in the table below:

# %% [markdown]
# ![Screenshot_11-4-2024_15912_learning.samatrix.io.jpeg](attachment:Screenshot_11-4-2024_15912_learning.samatrix.io.jpeg)

# %% [markdown]
# # Write a python program that accepts year, month, and day from the user. The year should be entered as an integer. The month should be entered as a string followed by the day within the month that should be entered as an integer. Once the user enters the year, the month, and the day, your program should display the zodiac associated with the date that was entered. Your program should check whether the date is valid. If should also check the leap year while checking the date for February. If the date is not valid, it should give a message

# %%
zodiacr = {
    "January": ("Capricorn", 22, 31),
    "February": ("Aquarius", 20, 18),
    "March": ("Pisces", 19, 20),
    "April": ("Aries", 21, 19),
    "May": ("Taurus", 20, 19),
    "June": ("Gemini", 21, 20),
    "July": ("Cancer", 21, 22),
    "August": ("Leo", 23, 22),
    "September": ("Virgo", 23, 22),
    "October": ("Libra", 23, 22),
    "November": ("Scorpio", 23, 21),
    "december": ("Sagittarius", 22, 21),
}

year = int(input("Enter your birth year: "))
month = input("Enter your birth month (e.g., January): ")
day = int(input("Enter your birth day: "))
if month not in zodiacr :
    print("Invalid birth month")
    exit()
zodiacname, month, day = zodiacr[month]
if (month, day) < (month, day):
    zodiacname = list(zodiacr.keys())[list(zodiacr.values()).index(zodiacname) - 1]

print(f"Your zodiac sign is {zodiacname}!")
# Out:
# Enter your birth year: 2006
# Enter your birth month (e.g., January): July
# Enter your birth day: 15
# Your zodiac sign is Cancer!

# %% [markdown]
# ![Screenshot_11-4-2024_153830_learning.samatrix.io.jpeg](attachment:Screenshot_11-4-2024_153830_learning.samatrix.io.jpeg)

# %%
n=float(input("enter your ratings from 0.0 to 1.0"))
if 0.0<=n<=0.3:
    print("Unacceptable performance")
elif 0.4<=n<=0.5:
    print("acceptable performance")
elif 0.6<=n<=1.1:
    print("meritorius performance")
else:
    print("invalid rating")
ir=n*200000
print("\n",ir, "is your annual incriment")
# Out:
# enter your ratings from 0.0 to 1.00.8
# meritorius performance
#
#  160000.0 is your annual incriment

# %% [markdown]
# # A zoo charges the admission fee based on the age of the guest. The admission charges for infants of age 2  years or less are not applicable. The guests between  3 and  12 years of age will be charged INR 500. For senior citizens aged 65 years and above the charges are INR 600. For all other citizens, the charges are INR 750. Write a program that prompts the user to enter the age of each guest in a group with one age entered on each line. Then your program should display the number of guests and total admission cost in two decimal places of the group with an appropriate message.

# %%
tc = 0
tg =0 
while True:
    age = input("Enter the age of the guest (or 'done' to finish): ")
    if age.lower() == 'done':
        break
    else:
        age = int(age)
        tg += 1
        if age <= 2:
            cost = 0
        elif 3 <= age <= 12:
            cost = 500
        elif age >= 65:
            cost = 600
        else:
            cost = 750
        tc += cost
print(f"\nTotal Guests: {tg}")
print(f"Total Admission Cost: INR {tc:.2f}")
# Out:
# Enter the age of the guest (or 'done' to finish): 644
# Enter the age of the guest (or 'done' to finish): 56
# Enter the age of the guest (or 'done' to finish): 546
# Enter the age of the guest (or 'done' to finish): 56
# Enter the age of the guest (or 'done' to finish): 45
# Enter the age of the guest (or 'done' to finish): 54
# Enter the age of the guest (or 'done' to finish): done
#
# Total Guests: 6
# Total Admission Cost: INR 4200.00

# %% [markdown]
# # A palindrome is a word, number, phrase, or other sequence of characters which reads the same backward as forward, such as madam or racecar or anna or civic or hannah. Write a program that reads a string from the user and uses a loop to determines whether or not it is a palindrome. Display the result, including a meaningful output message.

# %%
so=input("enter the palindrome drome string")
s=list(so)
si=s[ : :-1]
if si==s:
    print("\n",so, "  the string is palindrome")
else:
    print("the string is not palindrome")
# Out:
# enter the palindrome drome stringcivic
#
#  civic   the string is palindrome
